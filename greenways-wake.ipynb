# %%
import pandas as pd

# %%
greenways = pd.read_csv("https://opendata.arcgis.com/datasets/3f75595edc244c35812675b226021258_0.csv")

# %%
greenways.head(10)
# Out:
#    OBJECTID                  CORRIDOR     TYPE    STATUS         TOWN  \
# 0      2671  Lake Wheeler Lake Benson           Proposed       Garner
# 1      2672          Steep Hill Creek           Proposed       Garner
# 2      2673          Steep Hill Creek           Proposed      Raleigh
# 3      2674              Lowery Creek           Proposed
# 4      2675              Hominy Creek           Proposed
# 5      2676          Cedar Fork Creek           Proposed   Rolesville
# 6      2677                                     Existing         Apex
# 7      2678                            On Road  Proposed      Wendell
# 8      2679                            On-Road  Proposed   Knightdale
# 9      2680                            On-Road  Proposed   Knightdale
#
#                                           SOURCE         FAC  \
# 0  Wake Co Open Space Land Acquisition Plan Ph 2    Greenway
# 1  Wake Co Open Space Land Acquisition Plan Ph 2    Greenway
# ...

# %%
greenways.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2680 entries, 0 to 2679
# Data columns (total 10 columns):
# OBJECTID     2680 non-null int64
# CORRIDOR     839 non-null object
# TYPE         2180 non-null object
# STATUS       2676 non-null object
# TOWN         2475 non-null object
# SOURCE       2675 non-null object
# FAC          2674 non-null object
# STATUSFAC    2680 non-null object
# NAME         1879 non-null object
# SHAPELEN     2680 non-null float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 209.4+ KB

# %%
greenways.NAME.value_counts()
# Out:
#                                            357
# Neuse River Trail                          161
# E Carroll Joyner Park Greenway              75
# White Oak Creek Greenway                    24
# Beaver Creek Greenway                       21
# Swift Creek Greenway                        21
# Little Rock Trail                           15
# Black Creek Greenway                        15
# Miller Park Greenway                        15
# Upper Neuse River Segment                   15
# Brentwood Trail                             14
# Apex Peakway                                14
# Lake Johnson Greenway                       13
# Davis Drive                                 11
# Dunn Creek Greenway                         10
# Kit Creek Greenway                          10
# Hatcher Grove Greenway                       9
# Sears Farm Rd Park Greenway                  9
# North Cary Park Greenway                     9
# Smith Creek Greenway                         9
# ...

# %%
greenways.NAME.value_counts().reset_index()
# Out:
#                                        index  NAME
# 0                                              357
# 1                          Neuse River Trail   161
# 2             E Carroll Joyner Park Greenway    75
# 3                   White Oak Creek Greenway    24
# 4                      Beaver Creek Greenway    21
# 5                       Swift Creek Greenway    21
# 6                          Little Rock Trail    15
# 7                       Black Creek Greenway    15
# 8                       Miller Park Greenway    15
# 9                  Upper Neuse River Segment    15
# 10                           Brentwood Trail    14
# 11                              Apex Peakway    14
# 12                     Lake Johnson Greenway    13
# 13                               Davis Drive    11
# 14                       Dunn Creek Greenway    10
# 15                        Kit Creek Greenway    10
# 16                    Hatcher Grove Greenway     9
# ...
